# %% [markdown]
# ![Web capture_28-6-2023_1173_.jpeg](<attachment:Web capture_28-6-2023_1173_.jpeg>)
# - this is AlexNet architecture which is used for image classification, object detection and localization
# - it has 5 convolutional layers and 3 fully connected layers
# - it has 60 million parameters and 650,000 neurons
# - this is the first architecture which used ReLU activation function

# %%
import tensorflow as tf

# %%
model = tf.keras.models.Sequential([
    tf.keras.Input(shape=[224, 224, 3]), # 224x224x3 is the size of the input image
    tf.keras.layers.Conv2D(filters=96, kernel_size=11, strides=4, activation='relu'), # 96 is the number of filters, 11 is the kernel size, 4 is the stride
    tf.keras.layers.Conv2D(filters=256, kernel_size=5, activation='relu'), # 256 is the number of filters, 5 is the kernel size
    tf.keras.layers.MaxPool2D(pool_size=2, strides=2), # 2 is the pool size, 2 is the stride #pool is basiclly a filter which is used to reduce the size of the image

    tf.keras.layers.Conv2D(filters=384, kernel_size=3, activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2, strides=2),

    tf.keras.layers.Conv2D(filters=384, kernel_size=3, activation='relu'),
    tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2, strides=2),

    tf.keras.layers.Flatten(), # Flatten the 3D output to 1D tensor

    # here we are using 3 hidden layer which are fully connected
    tf.keras.layers.Dense(4096, activation='relu'), # 4096 is the number of neurons in the hidden layer and i use relu as activation function becasue it is best for hidden layer
    tf.keras.layers.Dense(4096, activation='relu'), 
    tf.keras.layers.Dense(len(CLASSES), activation='softmax')  #CLASS is the list of flower name are present in 104-flowers dataset
])

model.compile(optimizer='Adam', # this is used to optimize the model
              loss='sparse_categorical_crossentropy', # this is used to calculate the loss of the model
              metrics = ['sparse_categorical_accuracy'], # this is used to calculate the accuracy of the model
              steps_per_execution=8) # this is used to speed up the training process

model.summary() # this will print the summary of the model like how many layers are present in the model and how many parameters are present in each layer

# %%
train_ds = () # Here is your training dataset
val_ds = () # Here is your validation dataset

history = model.fit(train_ds, # this is the training dataset    
                    validation_data=val_ds, # this is the validation dataset
                    epochs=10, # this is the number of epochs
                    steps_per_epoch=8, # this is the number of steps per epoch
                    validation_steps=8,  # this is the number of validation steps
                    )
